# %% [markdown]
# <a href="https://colab.research.google.com/github/fofsinx/echo.dataset/blob/data/prepare_transcriptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/fofsinx/echo.dataset

# %%
# !pip install faster_whisper pandas
# Out:
# Collecting faster_whisper
#   Downloading faster_whisper-1.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Collecting ctranslate2<5,>=4.0 (from faster_whisper)
#   Downloading ctranslate2-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in /opt/conda/lib/python3.10/site-packages (from faster_whisper) (0.25.1)
# Requirement already satisfied: tokenizers<1,>=0.13 in /opt/conda/lib/python3.10/site-packages (from faster_whisper) (0.20.0)
# Collecting onnxruntime<2,>=1.14 (from faster_whisper)
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting av>=11 (from faster_whisper)
#   Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from faster_whisper) (4.66.4)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from ctranslate2<5,>=4.0->faster_whisper) (70.0.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in /opt/conda/lib/python3.10/site-packages (from ctranslate2<5,>=4.0->faster_whisper) (6.0.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (4.12.2)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster_whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (24.3.25)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (1.13.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.13->faster_whisper) (3.1.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster_whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime<2,>=1.14->faster_whisper) (1.3.0)
# Downloading faster_whisper-1.1.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.9 MB/s eta 0:00:0000:01
# Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 46.2 MB/s eta 0:00:00:00:0100:01
# Downloading ctranslate2-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 38.0 MB/s eta 0:00:00:00:0100:01
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 54.9 MB/s eta 0:00:0000:010:01m
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, ctranslate2, av, coloredlogs, onnxruntime, faster_whisper
# Successfully installed av-13.1.0 coloredlogs-15.0.1 ctranslate2-4.5.0 faster_whisper-1.1.0 humanfriendly-10.0 onnxruntime-1.20.1

# %%
import os

import uuid

import csv

import concurrent.futures

from faster_whisper import WhisperModel

import pandas as pd

import logging



# Set up logging

logging.basicConfig(level=logging.INFO)

logger = logging.getLogger(__name__)



# Initialize Whisper model with GPU

model = WhisperModel("large-v3", device="cuda", compute_type="float16")
# Out:
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# vocabulary.json:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.39k [00:00<?, ?B/s]

# %%
def transcribe_audio(row):

    """Transcribe a single audio file using Whisper model"""

    try:

        print(f"🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: {row['path']}")

        segments, _ = model.transcribe(row['path'])

        transcription = " ".join([segment.text for segment in segments])

        return {

            'id': row['id'],

            'path': row['path'],

            'transcription': transcription

        }

    except Exception as e:

        print(f"❌ Error processing {row['path']}: {str(e)}")

        return {

            'id': row['id'],

            'path': row['path'],

            'transcription': ''

        }



def process_csv_file(csv_path, base_path):

    """Process a CSV file and add transcriptions"""

    try:

        # Read CSV file

        df = pd.read_csv(csv_path)

        print(f"📊 File: prepare.py, Line: 35, Function: process_csv_file, Processing CSV: {csv_path}")



        # Create ThreadPoolExecutor for parallel processing

        with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:

            # Process each row in parallel

            # Add base path to each record

            records = df.to_dict('records')

            for record in records:

                record['path'] = f"{base_path}/{record['path']}"

            results = list(executor.map(transcribe_audio, records))



        # Create new DataFrame with results

        new_df = pd.DataFrame(results)



        # Save back to CSV

        new_df.to_csv(csv_path, index=False)

        print(f"✅ Successfully processed {csv_path}")



    except Exception as e:

        print(f"❌ Error processing CSV {csv_path}: {str(e)}")



def get_folders(parent_path):

    return [os.path.join(parent_path, f) for f in os.listdir(parent_path) if os.path.isdir(os.path.join(parent_path, f))]


# Main execution

if __name__ == "__main__":

    folders = [

        'vale',

        'maple',

        'glimmer',

        'juniper'

    ]

    base_path = "echo.dataset"

    for folder in folders:

        process_csv_file(os.path.join(base_path, folder, f"{folder}_dataset.csv"), os.path.join(base_path, folder))
# Out:
# 📊 File: prepare.py, Line: 35, Function: process_csv_file, Processing CSV: echo.dataset/vale/vale_dataset.csv
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_016.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_016.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_016.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_016.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_016.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_016.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_000.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_005.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_011.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_005.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_005.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_010.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_010.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_010.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_010.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_010.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_010.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_011.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_011.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_000.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_000.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/52d4ef64-64bf-421c-b642-9fad120bca8b_000.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_004.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/52d4ef64-64bf-421c-b642-9fad120bca8b_000.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/52d4ef64-64bf-421c-b642-9fad120bca8b_000.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_004.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_004.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_004.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_003.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_004.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_004.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_019.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_012.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/6a7f5ca4-eee8-4dab-bbc3-b4584b8901af_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_019.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_019.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f0c87b3d-51c9-48f8-81d8-081a62f8e8c0_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_012.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_012.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_006.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/6a7f5ca4-eee8-4dab-bbc3-b4584b8901af_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/6a7f5ca4-eee8-4dab-bbc3-b4584b8901af_003.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f0c87b3d-51c9-48f8-81d8-081a62f8e8c0_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f0c87b3d-51c9-48f8-81d8-081a62f8e8c0_003.wav'
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_006.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_006.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_025.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_011.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_025.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_025.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d50ceadb-8356-4c0c-b47f-f52c02672d2f_006.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d50ceadb-8356-4c0c-b47f-f52c02672d2f_006.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d50ceadb-8356-4c0c-b47f-f52c02672d2f_006.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_005.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_011.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_011.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_016.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/0a32fb2c-ed59-4b74-9dea-eee0d4974eaf_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_010.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4c10be5-1029-4829-81ff-ff838e875cc2_007.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_016.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_016.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/67b093dc-4b2d-4776-94ae-cc338a9b64b9_005.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_004.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4c10be5-1029-4829-81ff-ff838e875cc2_007.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4c10be5-1029-4829-81ff-ff838e875cc2_007.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/c2f7aad0-0bb9-4433-9a54-55532ad8fdec_008.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_005.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_005.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/05ebd845-60ca-4846-8ae1-bfd09384d6ef_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/67b093dc-4b2d-4776-94ae-cc338a9b64b9_005.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/67b093dc-4b2d-4776-94ae-cc338a9b64b9_005.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4c2efd5-59fd-473c-ab56-a43b614db3fa_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_010.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_010.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4c2efd5-59fd-473c-ab56-a43b614db3fa_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_004.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_004.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/05ebd845-60ca-4846-8ae1-bfd09384d6ef_000.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/c2f7aad0-0bb9-4433-9a54-55532ad8fdec_008.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/c2f7aad0-0bb9-4433-9a54-55532ad8fdec_008.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_005.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/05ebd845-60ca-4846-8ae1-bfd09384d6ef_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/05ebd845-60ca-4846-8ae1-bfd09384d6ef_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/67b093dc-4b2d-4776-94ae-cc338a9b64b9_004.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/c2f7aad0-0bb9-4433-9a54-55532ad8fdec_009.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4c2efd5-59fd-473c-ab56-a43b614db3fa_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4c2efd5-59fd-473c-ab56-a43b614db3fa_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4c10be5-1029-4829-81ff-ff838e875cc2_006.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/05ebd845-60ca-4846-8ae1-bfd09384d6ef_000.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/05ebd845-60ca-4846-8ae1-bfd09384d6ef_000.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_011.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_005.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_005.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/0a32fb2c-ed59-4b74-9dea-eee0d4974eaf_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/67b093dc-4b2d-4776-94ae-cc338a9b64b9_004.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/67b093dc-4b2d-4776-94ae-cc338a9b64b9_004.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_004.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/c2f7aad0-0bb9-4433-9a54-55532ad8fdec_009.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/c2f7aad0-0bb9-4433-9a54-55532ad8fdec_009.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d50ceadb-8356-4c0c-b47f-f52c02672d2f_007.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4c10be5-1029-4829-81ff-ff838e875cc2_006.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4c10be5-1029-4829-81ff-ff838e875cc2_006.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_017.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_011.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/11afa18d-678a-47f9-8990-7ed8e1d53be4_011.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/0a32fb2c-ed59-4b74-9dea-eee0d4974eaf_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/0a32fb2c-ed59-4b74-9dea-eee0d4974eaf_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_010.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_004.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_004.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_007.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d50ceadb-8356-4c0c-b47f-f52c02672d2f_007.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d50ceadb-8356-4c0c-b47f-f52c02672d2f_007.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_024.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_017.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_017.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f0c87b3d-51c9-48f8-81d8-081a62f8e8c0_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8c6ce126-5417-4950-8ea2-1d19b9b48b8d_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/6a7f5ca4-eee8-4dab-bbc3-b4584b8901af_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_010.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/72162576-86e3-4778-937f-cf7f8e352659_010.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_013.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_007.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_007.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_018.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_024.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_024.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f0c87b3d-51c9-48f8-81d8-081a62f8e8c0_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f0c87b3d-51c9-48f8-81d8-081a62f8e8c0_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/6a7f5ca4-eee8-4dab-bbc3-b4584b8901af_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/6a7f5ca4-eee8-4dab-bbc3-b4584b8901af_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_000.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_013.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca_013.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/52d4ef64-64bf-421c-b642-9fad120bca8b_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_018.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_018.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_005.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_005.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_000.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_000.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_011.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/52d4ef64-64bf-421c-b642-9fad120bca8b_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/52d4ef64-64bf-421c-b642-9fad120bca8b_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_011.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_005.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_005.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_010.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_004.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_005.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_005.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_011.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_011.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_011.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_011.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_017.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_010.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_010.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/b4b3ae3d-4587-4de0-a1a3-5cb2016d77dd.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_004.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_004.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_017.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_029.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_017.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_017.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_008.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/b4b3ae3d-4587-4de0-a1a3-5cb2016d77dd.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/b4b3ae3d-4587-4de0-a1a3-5cb2016d77dd.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_015.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_017.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_017.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f45da22e-fd72-4bbe-aa03-0510836a7459_009.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_029.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_029.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_015.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_008.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_008.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_015.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_015.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_003.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_012.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/f45da22e-fd72-4bbe-aa03-0510836a7459_009.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/f45da22e-fd72-4bbe-aa03-0510836a7459_009.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_006.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_015.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_015.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/e3629402-541e-4baa-bb77-cc1beee613e1_009.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_000.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_003.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_003.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_007.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_012.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_012.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_007.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_006.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/7ba8e381-84d4-4c27-905e-9732eda463a5_006.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_013.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/e3629402-541e-4baa-bb77-cc1beee613e1_009.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/e3629402-541e-4baa-bb77-cc1beee613e1_009.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_000.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/3dc61495-2126-4949-a3fe-8bcdd42b2417_000.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_002.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_007.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_007.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_015.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_007.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d2de73c0-d350-4bcf-8a6d-acb673766dda_007.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/6cd24d74-3804-4502-b453-6ea9e1e76547_009.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_013.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/9f50a730-f7d3-4f55-b7e4-666bf9eb333c_013.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_001.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_001.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/dede4efd-a8c8-4085-978f-17557d321423_001.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/d033299f-1579-49cd-977f-3e8bf8e2a336_026.wav
# ❌ Error processing echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_002.wav: [Errno 2] No such file or directory: 'echo.dataset/vale/echo.dataset/vale/d74d6ffd-60df-49ca-8390-c342c215b100_002.wav'
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/vale/echo.dataset/vale/f4deae44-6b88-4c28-b27d-fcac021f99ca
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/d131c113-ffa1-429c-9a1c-340fa8235f41_000.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/d131c113-ffa1-429c-9a1c-340fa8235f41_000.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/f45da22e-fd72-4bbe-aa03-0510836a7459_007.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/f45da22e-fd72-4bbe-aa03-0510836a7459_007.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_006.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_006.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_027.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_027.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_012.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/62c203a3-5d1d-4b15-ad3a-6dbbb64bc69f_012.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/d033299f-1579-49cd-977f-3e8bf8e2a336_014.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/d033299f-1579-49cd-977f-3e8bf8e2a336_014.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/6cd24d74-3804-4502-b453-6ea9e1e76547_013.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/6cd24d74-3804-4502-b453-6ea9e1e76547_013.wav'
# ❌ Error processing echo.dataset/maple/echo.dataset/maple/b34e5529-222a-4e79-b3bb-1824efff4ab9_001.wav: [Errno 2] No such file or directory: 'echo.dataset/maple/echo.dataset/maple/b34e5529-222a-4e79-b3bb-1824efff4ab9_001.wav'
# ✅ Successfully processed echo.dataset/maple/maple_dataset.csv
# 📊 File: prepare.py, Line: 35, Function: process_csv_file, Processing CSV: echo.dataset/glimmer/glimmer_dataset.csv
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_016.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/8bbfa9a3-bc15-4cf9-b362-03ef2e8ad5ad_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/13c1892d-14d0-46a8-9a8d-0cc48bc645f2_016.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/b3b3e1b2-bd36-40d1-ac21-3c8c140d9e67_000.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/7ba8e381-84d4-4c27-905e-9732eda463a5_005.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/7ba8e381-84d4-4c27-905e-9732eda463a5_011.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/d2de73c0-d350-4bcf-8a6d-acb673766dda_010.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/0d2a7547-50e9-40fc-b3c7-02e677cef193_001.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/52d4ef64-64bf-421c-b642-9fad120bca8b_000.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/3dc61495-2126-4949-a3fe-8bcdd42b2417_003.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/d2de73c0-d350-4bcf-8a6d-acb673766dda_004.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/d74d6ffd-60df-49ca-8390-c342c215b100_001.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/dede4efd-a8c8-4085-978f-17557d321423_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/1a1293a2-cde3-4a88-a0b9-5fecd6d7f3f3_002.wav
# 🎯 File: prepare.py, Line: 16, Function: transcribe_audio, Processing file: echo.dataset/glimmer/935ded14-29bd-4ce2-bada-91ce7983305d_013.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 116
#     112 base_path = "echo.dataset"
#     114 for folder in folders:
# --> 116     process_csv_file(os.path.join(base_path, folder, f"{folder}_dataset.csv"), os.path.join(base_path, folder))
#
# Cell In[3], line 67, in process_csv_file(csv_path, base_path)
#      63     for record in records:
#      65         record['path'] = f"{base_path}/{record['path']}"
# ---> 67     results = list(executor.map(transcribe_audio, records))
#      71 # Create new DataFrame with results
#      73 new_df = pd.DataFrame(results)
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File /opt/conda/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
